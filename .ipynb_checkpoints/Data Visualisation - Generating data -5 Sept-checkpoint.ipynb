# %% [markdown]
# ## Calculating Data Automatically
#
# Writing lists by hand can be inefficient, especially when we have many points.
# Rather than passing our points in a list, we can use a loop in Python to do the calculations for us.

# %%
import matplotlib.pyplot as plt
x_points = range(1,1001)
y_points = [x**2 for x in x_points]

# use seaborn style
plt.style.use('seaborn')
fig, ax = plt.subplots()

ax.set_title('Another One',fontsize=20)
ax.set_xlabel('Values',fontsize=20)
ax.set_ylabel('Squares',fontsize=20)
ax.scatter(x_points,y_points,s=10)

## set the range for each axis - explain
ax.axis([0,1100,0,1100000])

plt.show()

# %% [markdown]
# ## Defining Custom Colors
# The color of points can be changed by passing the variable to the scatter method

# %%
import matplotlib.pyplot as plt
x_points = range(1,1001)
y_points = [x**2 for x in x_points]

# use seaborn style
plt.style.use('seaborn')
fig, ax = plt.subplots()

# you can also use  hexadecimal notation  and rgb and text to select your color
# read about hexadecimal and rgb color notation
#text
ax.scatter(x_points,y_points,s=10,c='cyan')

# #hexa decimal
# ax.scatter(x_points,y_points,s=10,c='#000')

#rgb
# ax.scatter(x_points,y_points,s=10,color=(0,1,0))
## Values closer to 0 produce dark colors, and values closer to 1 produce lighter colors.

## set the range for each axis - explain
ax.axis([0,1100,0,1100000])

plt.show()

# %% [markdown]
# ## Using a Colormap
#
# A colormap is a series of colors in a gradient that moves from a starting to an ending color.
# Colormaps are used in visualizations to emphasize a pattern in the data.
# For example, you might make low values a light color and high values a darker color.
# he pyplot module includes a set of built-in colormaps. To use one of these colormaps, you need to specify how pyplot should assign a color to each point in the data set.

# %%
import matplotlib.pyplot as plt
x_points = range(1,1001)
y_points = [x**2 for x in x_points]

# use seaborn style
plt.style.use('seaborn')
fig, ax = plt.subplots()



ax.scatter(x_points, y_points, c=y_points, cmap=plt.cm.cool, s=10)

## set the range for each axis - explain
ax.axis([0,1100,0,1100000])

plt.show()

# %% [markdown]
# You can see all the colormaps available in pyplot at https://matplotlib.org/; go to Examples, scroll down to Color, and click Colormap reference.

# %% [markdown]
# ### Saving Your Plots Automatically
#
# If you want your program to automatically save the plot to a file, you can replace the call to plt.show() with a call to plt.savefig():

# %%
import matplotlib.pyplot as plt
x_points = range(1,1001)
y_points = [x**2 for x in x_points]

# use seaborn style
plt.style.use('seaborn')
fig, ax = plt.subplots()



ax.scatter(x_points, y_points, c=y_points, cmap=plt.cm.copper, s=10)

## set the range for each axis - explain
ax.axis([0,1100,0,1100000])

# plt.show()
plt.savefig('squares_plot.pdf', bbox_inches='tight')

# %% [markdown]
#   ## try this
#
#  Cubes: A number raised to the third power is a cube. Plot the first five cubic numbers, and then plot the first 5000 cubic numbers.
# Colored Cubes: Apply a colormap to your cubes plot.

# %% [markdown]
# # Random Walks
#
# A random walk is a path that has no clear direction but is determined by a series of random decisions, each of which is left entirely to chance. You might imagine a random walk as the path a confused ant would take if it took every step in a random direction.
#
# We are going to use Python to generate data for a random walk, and then use Matplotlib to create a visually appealing representation of that data.
#
# Random walks have practical applications in nature, physics, biology, chemistry, and economics. For example, a pollen grain floating on a drop of water moves across the surface of the water because it’s constantly pushed around by water molecules. Molecular motion in a water drop is random, so the path a pollen grain traces on the surface is a random walk. The code we’ll write next models many realworld situations.
#
# ## Creating the RandomWalk() Class
# The class needs three attributes: one variable to store the number of points in the walk and two lists to store the x and y-coordinate values of each point in the walk.
# We’ll only need two methods for the RandomWalk class: the __init__() method and fill_walk(), which will calculate the points in the walk. Let’s start with __init__() as shown here:

# %%
from random import choice
class RandomWalk:
    """A class to generate random walks."""
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        # All walks start at (0, 0). 
        self.x_values = [0]
        self.y_values = [0]

## Choosing Directions
#Let's define a fill_walk() method and use it to fill our walk with points and determine the direction of each step

    def fill_walk(self):
        """Calculate all the points in the walk."""
        # Keep taking steps until the walk reaches the desired length.  
        while len(self.x_values) < self.num_points:
        # Decide which direction to go and how far to go in that direction. 
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance

            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance


            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue

            # Calculate the new position.
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)
            
            
import matplotlib.pyplot as plt
# from random_walk import RandomWalk
# Make a random walk. 
rw = RandomWalk()
rw.fill_walk()
# Plot the points in the walk. 
plt.style.use('classic')
fig, ax = plt.subplots()

ax.scatter(rw.x_values, rw.y_values, s=15)
plt.show()

# %% [markdown]
# ### Generating Multiple Random Walks
# Every random walk is different, and it’s fun to explore the various patterns that can be generated. One way to use the preceding code to make multiple walks without having to run the program several times is to wrap it in a while loop, like this:

# %%
import matplotlib.pyplot as plt
from random import choice
class RandomWalk:
    """A class to generate random walks."""
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        # All walks start at (0, 0). 
        self.x_values = [0]
        self.y_values = [0]

## Choosing Directions
#Let's define a fill_walk() method and use it to fill our walk with points and determine the direction of each step

    def fill_walk(self):
        """Calculate all the points in the walk."""
        # Keep taking steps until the walk reaches the desired length.  
        while len(self.x_values) < self.num_points:
        # Decide which direction to go and how far to go in that direction. 
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance

            y_direction = choice([1, -1])
            y_distance = choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance


            # Reject moves that go nowhere.
            if x_step == 0 and y_step == 0:
                continue

            # Calculate the new position.
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)
            
# Keep making new walks, as long as the program is active. 
while True:
    # Make a random walk. 
    rw = RandomWalk() 
    rw.fill_walk()
    # Plot the points in the walk. 
    plt.style.use('classic')
    fig, ax = plt.subplots(figsize=(15,9)) 
    ax.scatter(rw.x_values, rw.y_values, s=15) 
    
    plt.show()
    keep_running = input("Make another walk? (y/n): ") 
    if keep_running == 'n':
        break
# Out:
# Make another walk? (y/n): y
# Make another walk? (y/n): n

# %% [markdown]
# ### Altering the Size to Fill the Screen
#
# fig, ax = plt.subplots(figsize=(15, 9))

# %% [markdown]
# ### Rolling dice of differerent sizes
